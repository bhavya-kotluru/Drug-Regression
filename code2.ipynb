# %% [raw]
# 1) mention about problem statement
# 2) talk about columns
# 3)install the models and required libraries
# 4)Load data set
# 5)understand your data
# 6)EDA
#  i)univariate analysis
#  ii)Bi-variate analysis
#  iii)Multivarivate analysis
# 7)check the null-values or missing values
#  i)treating the null values(fill with mean or median or mode)
#  ii)drop null values if they are less than 5%-10%
# 8)check the duplicates
#  i)drop duplicates
# 9)treating the ouliers
#  i)check the outliers
#  ii)remove outliers
#  iii)make the box plot before and after the outliers
# 10)Feature engineering
#  a)i)extract the features
#   ii)create the features
#   iii)select the features
#  b)checking the multicoliniarity
#  i)heat map
#  ii)vif technique
#  c)transformation
#  i)one hot encoding or label encoding
#  d)scaling(min_max_scalar)
#  11)X-y features split
#  12)train test split

# %% [raw]
# problem Statement
#
# Many people take medicines, but not all drugs work the same way for everyone. Some people feel better, while others experience side effects or no improvement. We want to build a system that predicts how satisfied a patient will be with a drug based on factors like their age, gender, health condition, and drug details.By using machine learning (regression models), we can estimate a satisfaction score for a drug before someone even takes it. This can help doctors and patients choose the best medication with fewer side effects and better results.

# %% [raw]
# columns in the Dataset
# numerical columns
# Reviews – The number of reviews available for the drug (e.g., "994 Reviews"). This might need to be converted into a numerical format.
# Effective – A numerical score indicating how effective the drug is (e.g., 2.52).
# EaseOfUse – A numerical score showing how easy the drug is to use (e.g., 3.01).
# Satisfaction – A numerical score reflecting user satisfaction with the drug (e.g., 1.84). This is likely the target variable for prediction.
# information columns
# Information – Additional details about the drug, likely in text format.
# Condition – The medical condition for which the drug is prescribed (e.g., "Acute Bacterial Sinusitis").
# Drug – The name of the medication given for the condition (e.g., "Levofloxacin").
# Indication Type – Describes if the drug is used for its intended purpose ("On Label") or for another condition ("Off Label").

# %%
# Import required library
import pandas as pd
# Load the dataset (replace 'your_file.csv' with your actual file name)
df = pd.read_csv(r"C:\Users\bhavya\Desktop\git\python-2\project\Drug_Data.csv")
# Separate categorical and numerical columns
categorical_columns = df.select_dtypes(include=['object']).columns.tolist()
numerical_columns = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
# Print the results
print("Categorical Columns:", categorical_columns)
print("Numerical Columns:", numerical_columns)
# Out:
# Categorical Columns: ['Condition', 'Drug', 'Indication', 'Type', 'Reviews', 'Information']
# Numerical Columns: ['Effective', 'EaseOfUse', 'Satisfaction']

# %%
# Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
print("All required libraries are successfully imported!")
# Out:
# All required libraries are successfully imported!

# %%
Condition_df = df['Condition'].value_counts().reset_index()
Condition_df.columns = ['Condition_Name', 'Count']
Condition_df.head()
# Out:
#                       Condition_Name  Count
# 0                              fever  13041
# 1                       hypertension  12284
# 2                  Atopic Dermatitis   9917
# 3                      endometriosis   8501
# 4  Bacterial Urinary Tract Infection   5929

# %%
plt.figure(figsize=(18,11))
plt.title('Top 5 product Name')
sns.barplot(x='Condition_Name',y='Count',data=Condition_df[:5])
# Out:
# <Axes: title={'center': 'Top 5 product Name'}, xlabel='Condition_Name', ylabel='Count'>

# %%
Drug_df = df['Drug'].value_counts().reset_index()
Drug_df.columns = ['Drug_Name', 'Count']
Drug_df.head()
# Out:
#                        Drug_Name  Count
# 0                  Acetaminophen   4562
# 1                      Ibuprofen   2453
# 2            Diphenhydramine Hcl   2278
# 3  Sulfamethoxazole-Trimethoprim   1729
# 4  Norethindrone-Ethin Estradiol   1694

# %%
plt.figure(figsize=(18,11))
plt.title('Top 5 product Name')
sns.barplot(x='Drug_Name',y='Count',data=Drug_df[:5])
# Out:
# <Axes: title={'center': 'Top 5 product Name'}, xlabel='Drug_Name', ylabel='Count'>

# %%
Indication_df = df['Indication'].value_counts().reset_index()
Indication_df.columns = ['Indication_Name', 'Count']
Indication_df.head()
# Out:
#   Indication_Name  Count
# 0        On Label  76879
# 1       Off Label  21872
# 2            \r\n   1775

# %%
plt.figure(figsize=(18,11))
plt.title('Top 3 product Name')
sns.barplot(x='Indication_Name',y='Count',data=Indication_df[:3])
# Out:
# <Axes: title={'center': 'Top 3 product Name'}, xlabel='Indication_Name', ylabel='Count'>
# ) missing from font(s) DejaVu Sans.packages\IPython\core\events.py:82: UserWarning: Glyph 13 (
#   func(*args, **kwargs)
# ) missing from font(s) DejaVu Sans.packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 13 (
#   fig.canvas.print_figure(bytes_io, **kw)
